# %%
#Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Wrangling

# %%
#Load data from home directory
df = pd.read_csv('../vehicles_us.csv')

# %%
#See info
df.info()
df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
#     price  model_year                     model  condition  cylinders fuel  \
# 0    9400      2011.0                    bmw x5       good        6.0  gas
# ...

# %%
# Validar filas duplicadas
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed]
# Index: []

# %%
# Validar cantidad promedio de valores nulos
df.isna().mean()
# Out:
# price           0.000000
# model_year      0.070238
# model           0.000000
# condition       0.000000
# cylinders       0.102086
# fuel            0.000000
# odometer        0.153168
# transmission    0.000000
# type            0.000000
# paint_color     0.179854
# is_4wd          0.503697
# date_posted     0.000000
# days_listed     0.000000
# dtype: float64

# %% [markdown]
# ### Columna price

# %%
df['price'].describe()
# Out:
# count     51525.000000
# mean      12132.464920
# std       10040.803015
# min           1.000000
# 25%        5000.000000
# 50%        9000.000000
# 75%       16839.000000
# max      375000.000000
# Name: price, dtype: float64

# %% [markdown]
# ### Columna model_year

# %%
df[df['model_year'].isna()]
# Out:
#        price  model_year                       model  condition  cylinders  \
# 1      25500         NaN                  ford f-150       good        6.0
# 20      6990         NaN             chevrolet tahoe  excellent        8.0
# 65     12800         NaN                  ford f-150  excellent        6.0
# 69      7800         NaN                  ford f-150   like new        8.0
# 72      3650         NaN              subaru impreza  excellent        NaN
# ...      ...         ...                         ...        ...        ...
# 51464   8890         NaN        ford f250 super duty       good        8.0
# 51465  34595         NaN                   gmc yukon  excellent        8.0
# 51487   1495         NaN                  ford f-150       fair        6.0
# 51488  21900         NaN  chevrolet silverado 3500hd  excellent        8.0
# 51508   4950         NaN     chrysler town & country  excellent        6.0
#
# ...

# %%
# Modificar tipo de datos de la columna model_year de flotante a entero
# Modificar valores nulos
df['model_year'] = df['model_year'].fillna(0).astype(int)

#Modificar tipo de datos
df['model_year'] = df['model_year'].astype(int)

# %% [markdown]
# ### Columna model

# %%
#Crear columna de brand
df['brand'] = df['model'].apply(lambda x: x.split()[0])

# %%
# Validar filas con valores ausentes en la columna model
df[df['model'].isna()]
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, brand]
# Index: []

# %%
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good        6.0  gas  145000.0
# 1  25500           0      ford f-150       good        6.0  gas   88705.0
# 2   5500        2013  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500        2003      ford f-150       fair        8.0  gas       NaN
# 4  14900        2017    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed     brand
# 0    automatic     SUV         NaN     1.0  2018-06-23           19       bmw
# 1    automatic  pickup       white     1.0  2018-10-19           50      ford
# 2    automatic   sedan         red     NaN  2019-02-07           79   hyundai
# 3    automatic  pickup         NaN     NaN  2019-03-22            9      ford
# 4    automatic   sedan       black     NaN  2019-04-02           28  chrysler

# %% [markdown]
# ### Columna condition

# %%
#Resumen de la columna
df['condition'].value_counts()
# Out:
# condition
# excellent    24773
# good         20145
# like new      4742
# fair          1607
# new            143
# salvage        115
# Name: count, dtype: int64

# %% [markdown]
# ### Columna cylinders

# %%
# Validar filas con valores ausentes en la columna cylinders
df[df['cylinders'].isna()]
# Out:
#        price  model_year              model  condition  cylinders fuel  \
# 9       9200        2008        honda pilot  excellent        NaN  gas
# 36     10499        2013       chrysler 300       good        NaN  gas
# 37      7500        2005      toyota tacoma       good        NaN  gas
# 59      5200        2006  toyota highlander       good        NaN  gas
# 63     30000        1966       ford mustang  excellent        NaN  gas
# ...      ...         ...                ...        ...        ...  ...
# 51429   3250        2004       toyota camry       good        NaN  gas
# 51442  28990        2018          ford f150  excellent        NaN  gas
# 51460   5995        2007        ford fusion  excellent        NaN  gas
# 51477   6499        2007           acura tl       good        NaN  gas
# 51486   5895        2009   hyundai santa fe  excellent        NaN  gas
#
#        odometer transmission         type paint_color  is_4wd date_posted  \
# ...

# %%
df['cylinders'].describe()
# Out:
# count    46265.000000
# mean         6.125235
# std          1.660360
# min          3.000000
# 25%          4.000000
# 50%          6.000000
# 75%          8.000000
# max         12.000000
# Name: cylinders, dtype: float64

# %% [markdown]
# ### columna fuel

# %%
df['fuel'].value_counts()
# Out:
# fuel
# gas         47288
# diesel       3714
# hybrid        409
# other         108
# electric        6
# Name: count, dtype: int64

# %%
# Validar filas con valores ausentes
df[df['fuel'].isna()]
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, brand]
# Index: []

# %% [markdown]
# ### Columna transmission

# %%
df['transmission'].value_counts()
# Out:
# transmission
# automatic    46902
# manual        2829
# other         1794
# Name: count, dtype: int64

# %%
# Validar filas con valores ausentes
df[df['transmission'].isna()]
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, brand]
# Index: []

# %% [markdown]
# ### Columna Type

# %%
df['type'].value_counts()
# Out:
# type
# SUV            12405
# truck          12353
# sedan          12154
# pickup          6988
# coupe           2303
# wagon           1541
# mini-van        1161
# hatchback       1047
# van              633
# convertible      446
# other            256
# offroad          214
# bus               24
# Name: count, dtype: int64

# %%
# Validar filas con valores ausentes
df[df['type'].isna()]
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, brand]
# Index: []

# %% [markdown]
# ### column paint_color

# %%
df['paint_color'].value_counts()
# Out:
# paint_color
# white     10029
# black      7692
# silver     6244
# grey       5037
# blue       4475
# red        4421
# green      1396
# brown      1223
# custom     1153
# yellow      255
# orange      231
# purple      102
# Name: count, dtype: int64

# %%
# Validar filas con valores ausentes
df[df['paint_color'].isna()]
# Out:
#        price  model_year                        model  condition  cylinders  \
# 0       9400        2011                       bmw x5       good        6.0
# 3       1500        2003                   ford f-150       fair        8.0
# 8      11500        2012                  kia sorento  excellent        4.0
# 12     18990        2012                     ram 1500  excellent        8.0
# 21      5250        2007                  toyota rav4       good        6.0
# ...      ...         ...                          ...        ...        ...
# 51502   7995        2011            chevrolet equinox   like new        4.0
# 51503   6595        2011             chevrolet malibu  excellent        4.0
# 51506  28900        2017  ford f150 supercrew cab xlt       good        6.0
# 51519  11750        2015                 honda accord  excellent        4.0
# 51524   6300        2014                nissan altima       good        4.0
#
# ...

# %%
# Rellenar los valores ausentes
df['paint_color'] = df['paint_color'].fillna('custom')

# %% [markdown]
# ### Columna is_4wd

# %%
df['is_4wd'] = df['is_4wd'].astype('object').fillna('No')

# %%
df['is_4wd'] = df['is_4wd'].replace(1.0,'Yes')

# %%
df.head(10)
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good        6.0  gas  145000.0
# 1  25500           0      ford f-150       good        6.0  gas   88705.0
# 2   5500        2013  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500        2003      ford f-150       fair        8.0  gas       NaN
# 4  14900        2017    chrysler 200  excellent        4.0  gas   80903.0
# 5  14990        2014    chrysler 300  excellent        6.0  gas   57954.0
# 6  12990        2015    toyota camry  excellent        4.0  gas   79212.0
# 7  15990        2013     honda pilot  excellent        6.0  gas  109473.0
# 8  11500        2012     kia sorento  excellent        4.0  gas  104174.0
# 9   9200        2008     honda pilot  excellent        NaN  gas  147191.0
#
#   transmission    type paint_color is_4wd date_posted  days_listed     brand
# 0    automatic     SUV       cutom    Yes  2018-06-23           19       bmw
# ...

# %% [markdown]
# ### Columna date_posted

# %%
# Validar filas con valores ausentes
df[df['date_posted'].isna()]
# Out:
# Empty DataFrame
# Columns: [price, model_year, model, condition, cylinders, fuel, odometer, transmission, type, paint_color, is_4wd, date_posted, days_listed, brand]
# Index: []

# %%
# Modificar tipo de datos a datetime
df['date_posted'] = pd.to_datetime(df['date_posted'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  datetime64[ns]
#  12  days_listed   51525 non-null  int64
#  13  brand         51525 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(3), object(7)
# memory usage: 5.5+ MB
